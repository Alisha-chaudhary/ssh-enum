# %%
from src.detection_tools.pattern_detector import EnumerationDetector

detector = EnumerationDetector('../data/sample-logs/enumeration-attempt.log')
alerts = detector.find_rapid_user_probes(window_seconds=60, threshold=5)
wordlist_hits = detector.find_wordlist_patterns('../data/wordlists/common-usernames-50.txt')
print('Rapid probe alerts:', alerts)
print('Wordlist matches:', wordlist_hits)
