# %%
from src.detection_tools.response_analyzer import ResponseAnalyzer

analyzer = ResponseAnalyzer()
result = analyzer.compare_responses(
    invalid_user_times=[0.312, 0.308, 0.315, 0.311, 0.309],
    valid_user_times=[0.311, 0.309, 0.314, 0.310, 0.312]
)
print(result)
# Expected: is_distinguishable = False, delta < 5ms
